# %%
import os
os.getcwd()
# Out:
# '/Users/deepthi/Desktop/HospitalReAdmissionPrediction/notebooks'

# %%
import pandas as pd

df=pd.read_csv("/Users/deepthi/Desktop/HospitalReAdmissionPrediction/Raw_data/Cleaned_data.csv");
df
# Out:
#            age  time_in_hospital  n_lab_procedures  n_procedures  \
# 0      [70-80)                 8                72             1
# 1      [70-80)                 3                34             2
# 2      [50-60)                 5                45             0
# 3      [70-80)                 2                36             0
# 4      [60-70)                 1                42             0
# ...        ...               ...               ...           ...
# 24995  [80-90)                14                77             1
# 24996  [80-90)                 2                66             0
# 24997  [70-80)                 5                12             0
# 24998  [70-80)                 2                61             3
# 24999  [50-60)                10                37             1
#
#        n_medications  n_outpatient  n_inpatient  n_emergency  \
# 0                 18             2            0            0
# ...
